# %% [markdown]
# # NMR Stack Processing

# %% [markdown]
# ## Import main processing function

# %%
import os

from process import process_stack, detect_spectra

# %matplotlib widget

# %% [markdown]
# ## Set processing parameters
#
# ### Filepath

# %%
filepath = '/Volumes/cctm/apavao/NMR/20230121_13CThr'

# %% [markdown]
# ### Isotope

# %%
# expt = '1H'
# expt = '13C'
expt = '1H_13Ced'

# %% [markdown]
# ### FID indices

# %%
init = '21'

# indices = detect_spectra(iso=isotope, init=init)  
indices = [str(3*i + 2) for i in range(22, 51)]
# indices = ['15'] #, '23']
# indices = ['91'] #, '14', '15']

# %% [markdown]
# ### Phase correction
# None to manually phase-correct, else a tuple (p0, p1)

# %%
# ps = None
ps = (-244., 190.4)

# %% [markdown]
# ### Dry run
# True to process without saving Excel data at the end (good for generating plots of individual spectra)
# False for normal behavior

# %%
dry_run = False

# %% [markdown]
# ## Call processing script

# %%
print("Welcome to NMR processing pipeline.\n")
print("Beginning calibration with following parameters:")
print("\t- Directory: " + filepath)
print("\t- Experiment type: " + expt)
print(f"\t- {expt} spectrum IDs: " + ', '.join(indices))
print("\t- Initial timepoint reference: " + init)
os.chdir(filepath)
process_stack(filepath, indices, initial=init, expt=expt, vb=True)
# Out:
# Welcome to NMR processing pipeline.
#
# Beginning calibration with following parameters:
# 	- Directory: /Volumes/cctm/apavao/NMR/20230121_13CThr
# 	- Experiment type: 1H_13Ced
# 	- 1H_13Ced spectrum IDs: 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146, 149, 152
# 	- Initial timepoint reference: 21
# Begin NMR stack process.
# Calibrate autophase and PPM shift...
# /Volumes/cctm/apavao/NMR/20230121_13CThr/68
# interactive(children=(FloatSlider(value=-0.0015926535897929917, description='phcorr0', max=3.141592653589793, …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
